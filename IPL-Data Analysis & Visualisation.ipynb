# %% [markdown]
# # IPL - Data Analysis & Visualisation

# %% [markdown]
# Krishna Singh
#
# ksjt1432000@gmail.com

# %% [markdown]
# ### IPL

# %% [markdown]
# The Indian Premier League (IPL) is a professional Twenty20 cricket league, contested by 8 teams based out of 8 different Indian cities. The league was founded by the Board of Control for Cricket in India (BCCI) in 2007. It is usually held between March and May of every year and has an exclusive window in the ICC Future Tours Programme.

# %% [markdown]
# ![IPL-teams-logo-design-breakdown-scaled.jpg](attachment:IPL-teams-logo-design-breakdown-scaled.jpg)

# %% [markdown]
# ## Aim of this Project

# %% [markdown]
# To analyse and visualise our dataset(containing data of IPL matches played in the period of 2008 - 2019) and then draw some conclusion from it.

# %% [markdown]
# # Section 1- Installing the required libraries

# %% [markdown]
# In this data Analysis We will be using various Python Libraries such as pandas, Numpy, Seaborn & Matplotlib,so first we need to install all these libraries.

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Reading data of matches.csv file using pandas library

# %%
ipl_df=pd.read_csv('matches.csv')
# By using .style we can view all data of ipl_df by scrolling it
ipl_df
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %% [markdown]
# To know about number of rows and columns of dataset we will use the .shape method

# %%
a,b=ipl_df.shape
'Total rows=%s and Total columns=%s'%(a,b)
# Out:
# 'Total rows=756 and Total columns=18'

# %% [markdown]
#  Now use .columns to check the names of all columns present in our dataset

# %%
ipl_df.columns
# Out:
# Index(['id', 'Season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %% [markdown]
# # Section 2 - Data Cleaning and Data Preparation

# %% [markdown]
# In this project,we would not using the umpires columns i.e ('umpire1', 'umpire2', 'umpire3').
# so to remove these columns we will use .drop() method

# %%
#inplace argument is used to make permanent changes in the dataframe(ipl_df) by setting it to True.
ipl_df.drop(columns=['umpire1','umpire2','umpire3'],inplace=True)

# Now we again check name of all columns to test the above functionality.
ipl_df.columns
# Out:
# Index(['id', 'Season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue'],
#       dtype='object')

# %%
# Now let us see all seasons in which IPL is played.
#.unique() is use to see the unique values in a particular column.
ipl_df["Season"].unique()
# Out:
# array(['IPL-2017', 'IPL-2008', 'IPL-2009', 'IPL-2010', 'IPL-2011',
#        'IPL-2012', 'IPL-2013', 'IPL-2014', 'IPL-2015', 'IPL-2016',
#        'IPL-2018', 'IPL-2019'], dtype=object)

# %% [markdown]
# In "Season" column,no data cleaning is required,because it contain all seasons that had been played so far

# %%
# Now Let us see all the teams that have played so far
ipl_df.team1.unique()
# Out:
# array(['Sunrisers Hyderabad', 'Mumbai Indians', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Royal Challengers Bangalore',
#        'Kolkata Knight Riders', 'Delhi Daredevils', 'Kings XI Punjab',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Rising Pune Supergiants',
#        'Delhi Capitals'], dtype=object)

# %%
# Now Let us see all the cities in which matches played so far
ipl_df.city.unique()
# Out:
# array(['Hyderabad', 'Pune', 'Rajkot', 'Indore', 'Bangalore', 'Mumbai',
#        'Kolkata', 'Delhi', 'Chandigarh', 'Kanpur', 'Jaipur', 'Chennai',
#        'Cape Town', 'Port Elizabeth', 'Durban', 'Centurion',
#        'East London', 'Johannesburg', 'Kimberley', 'Bloemfontein',
#        'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala', 'Kochi',
#        'Visakhapatnam', 'Raipur', 'Ranchi', 'Abu Dhabi', 'Sharjah', nan,
#        'Mohali', 'Bengaluru'], dtype=object)

# %% [markdown]
# ### From above observations ,some Data cleaning is required
# 1. Pune was represented by various Team Names as 'Rising Pune Supergiant', 'Pune Warriors' & 'Rising Pune Supergiants' so as a convinience we will changes these with the recent team representing Pune 'Rising Pune Supergiant' in all columns involving this name i.e 'team1','team2','winner' & 'toss_winner' columns.
# 2. Similarly 2nd Change is in team name of Delhi ,Earlier the team name for delhi was 'Delhi Daredevils' but later it was changed to 'Delhi Capitals' so we will replace the "delhi Daredevils' with 'Delhi Capitals'.
# 3. Bangalore was Renamed as Bengaluru in 2014 so we will change the Name for City Bangalore to Bengaluru to avoid Errors in Data Analysis

# %%
# To accomplish the above mentioned cleaning we will use .replace() method.
ipl_df.team1.replace({'Rising Pune Supergiants' : 'Rising Pune Supergiant', 'Delhi Daredevils':'Delhi Capitals','Pune Warriors' : 'Rising Pune Supergiant'},inplace=True)
ipl_df.team2.replace({'Rising Pune Supergiants' : 'Rising Pune Supergiant', 'Delhi Daredevils':'Delhi Capitals','Pune Warriors' : 'Rising Pune Supergiant'},inplace=True)
ipl_df.toss_winner.replace({'Rising Pune Supergiants' : 'Rising Pune Supergiant', 'Delhi Daredevils':'Delhi Capitals','Pune Warriors' : 'Rising Pune Supergiant'},inplace=True)
ipl_df.winner.replace({'Rising Pune Supergiants' : 'Rising Pune Supergiant', 'Delhi Daredevils':'Delhi Capitals','Pune Warriors' : 'Rising Pune Supergiant'},inplace=True)
ipl_df.city.replace({'Bangalore' : 'Bengaluru'},inplace=True)

# %% [markdown]
# Now it's time to check the result of above cleaning.

# %%
ipl_df.team1.unique()
# Out:
# array(['Sunrisers Hyderabad', 'Mumbai Indians', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Royal Challengers Bangalore',
#        'Kolkata Knight Riders', 'Delhi Capitals', 'Kings XI Punjab',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Deccan Chargers',
#        'Kochi Tuskers Kerala'], dtype=object)

# %%
ipl_df.team2.unique()
# Out:
# array(['Royal Challengers Bangalore', 'Rising Pune Supergiant',
#        'Kolkata Knight Riders', 'Kings XI Punjab', 'Delhi Capitals',
#        'Sunrisers Hyderabad', 'Mumbai Indians', 'Gujarat Lions',
#        'Rajasthan Royals', 'Chennai Super Kings', 'Deccan Chargers',
#        'Kochi Tuskers Kerala'], dtype=object)

# %%
ipl_df.toss_winner.unique()
# Out:
# array(['Royal Challengers Bangalore', 'Rising Pune Supergiant',
#        'Kolkata Knight Riders', 'Kings XI Punjab', 'Sunrisers Hyderabad',
#        'Mumbai Indians', 'Gujarat Lions', 'Delhi Capitals',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Deccan Chargers',
#        'Kochi Tuskers Kerala'], dtype=object)

# %%
ipl_df.winner.unique()
# Out:
# array(['Sunrisers Hyderabad', 'Rising Pune Supergiant',
#        'Kolkata Knight Riders', 'Kings XI Punjab',
#        'Royal Challengers Bangalore', 'Mumbai Indians', 'Delhi Capitals',
#        'Gujarat Lions', 'Chennai Super Kings', 'Rajasthan Royals',
#        'Deccan Chargers', 'Kochi Tuskers Kerala', nan], dtype=object)

# %%
ipl_df.city.unique()
# Out:
# array(['Hyderabad', 'Pune', 'Rajkot', 'Indore', 'Bengaluru', 'Mumbai',
#        'Kolkata', 'Delhi', 'Chandigarh', 'Kanpur', 'Jaipur', 'Chennai',
#        'Cape Town', 'Port Elizabeth', 'Durban', 'Centurion',
#        'East London', 'Johannesburg', 'Kimberley', 'Bloemfontein',
#        'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala', 'Kochi',
#        'Visakhapatnam', 'Raipur', 'Ranchi', 'Abu Dhabi', 'Sharjah', nan,
#        'Mohali'], dtype=object)

# %% [markdown]
# So We had successfully cleaned our messy or misspelled data.

# %% [markdown]
# ## Now we'll check NaN(null values) present in our dataset.

# %%
#Use of .isna() is to set NaN values of each column to True and use of .sum() is to calculate total NaN present
#in each column
ipl_df.isna().sum()
# Out:
# id                 0
# Season             0
# city               7
# date               0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# result             0
# dl_applied         0
# winner             4
# win_by_runs        0
# win_by_wickets     0
# player_of_match    4
# venue              0
# dtype: int64

# %%
#To find total null values present in our dataset
ipl_df.isna().sum().sum()
# Out:
# 15

# %% [markdown]
# Our next step is to search all NaN values in our dataset

# %%
#it'll return all rows having atleast one NaN value in any column
#axis=1 is used for vertical axis i.e for columns.
NaN_df = ipl_df[ipl_df.isna().any(axis=1)]
#To make the seaching easier ,use style.highlight_null to highlight all null values present in our dataframe with red colour
NaN_df.style.highlight_null(null_color='red')
# Out:
# <style type="text/css">
# #T_b5b31_row0_col10, #T_b5b31_row0_col13, #T_b5b31_row1_col2, #T_b5b31_row2_col2, #T_b5b31_row3_col2, #T_b5b31_row4_col2, #T_b5b31_row5_col2, #T_b5b31_row6_col2, #T_b5b31_row7_col2, #T_b5b31_row8_col10, #T_b5b31_row8_col13, #T_b5b31_row9_col10, #T_b5b31_row9_col13, #T_b5b31_row10_col10, #T_b5b31_row10_col13 {
#   background-color: red;
# }
# </style>
# <table id="T_b5b31_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >id</th>
#       <th class="col_heading level0 col1" >Season</th>
#       <th class="col_heading level0 col2" >city</th>
#       <th class="col_heading level0 col3" >date</th>
#       <th class="col_heading level0 col4" >team1</th>
#       <th class="col_heading level0 col5" >team2</th>
#       <th class="col_heading level0 col6" >toss_winner</th>
#       <th class="col_heading level0 col7" >toss_decision</th>
#       <th class="col_heading level0 col8" >result</th>
# ...

# %% [markdown]
# ## Handling of missing data

# %% [markdown]
# From above observation we conclude that:-
#
# 1) In "city" column ,NaN value represent, stadium location is "Dubai",so we need to replace all NaN values in "city" column with "Dubai".We Can See, these null values are at index 461,462,466,468,469,474,476.
#
# 2) In "winner" and "player_of_match" columns,NaN values are present in Case When Match had "No Result" so we Can assume the Match might have been a Draw or Cancelled Due to Some Weather Or Technical Conditions.So we will replace them with "Draw/cancelled",these null values are at index 300,545,570,744.

# %%
# loc() method is use to locate any data of our dataset based on it's index.
#it'll set city of all these indexes to "Dubai".
ipl_df.loc[[461,462,466,468,469,474,476],'city'] = "Dubai"

# %%
# To examine the above change
#We will use apply method and create a function to highlight the cities with name Dubai 
def highlight_data(x):
    # we make a copy of our dataframe so it'll not affect original dataframe
    df=x.copy()
    #set background colour of all data to white
    df.loc[:,:]='background-color:white'
    #it'll overwrite the colour
    df.city.loc[461,462,466,468,469,474,476]='background-color:lightgreen'
    return df
# Pandas.apply allow the users to pass a function and apply it on every single value of the Pandas series
ipl_df.loc[461:480].style.apply(highlight_data,axis=None)
# Out:
# <style type="text/css">
# ...

# %%
#fillna() is used for handling NaN values in dataset
#it will replace NaN values of "winner" and "player_of_match" column with "Draw/Cancelled".
ipl_df.fillna({"winner":"Draw/Cancelled","player_of_match":"Draw/Cancelled"},inplace=True)

# %%
# To examine the above change
ipl_df.loc[[300,545,570,744]]
def highlight_data(x):
    df=x.copy()
    df.loc[:,:]='background-color:white'
    df.winner.loc[300,545,570,744]='background-color:lightgreen'
    df.player_of_match.loc[300,545,570,744]='background-color:lightgreen'
    return df
ipl_df.loc[[300,545,570,744]].style.apply(highlight_data,axis=None)
# Out:
# <style type="text/css">
# ...

# %%
# Now let us check again whether any null value left in our dataset
ipl_df.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# Now it is clear that no null value is left in our data set
# So we are done with our data cleaning and data preparation part and can move to next step.

# %% [markdown]
# # Section 3 - Exploratory Analysis and Visualization

# %% [markdown]
# ### Now We Will Analyse the Data For Different types of Queries

# %%
#first we'll find the total Number of Matches Played from year 2008 to 2019.
ipl_df.id.count()
# Out:
# 756

# %% [markdown]
# So from 2008 to 2019, total 756 matches has been played.

# %%
#Second we find total number of matches Where Result Was tie
#this command will set value of all columnns to count of tie matches. 
regular_matches = ipl_df[ipl_df.result == 'tie'].count()
#By accessing the result column,we can access the total count of tie matches
regular_matches.result
# Out:
# 9

# %% [markdown]
# So from 756 matches,result of total 9 matches was tie.

# %% [markdown]
# ### Total matches played in each city

# %% [markdown]
# first we check the name of all cities where matches had been played.

# %%
ipl_df.city.unique()
# Out:
# array(['Hyderabad', 'Pune', 'Rajkot', 'Indore', 'Bengaluru', 'Mumbai',
#        'Kolkata', 'Delhi', 'Chandigarh', 'Kanpur', 'Jaipur', 'Chennai',
#        'Cape Town', 'Port Elizabeth', 'Durban', 'Centurion',
#        'East London', 'Johannesburg', 'Kimberley', 'Bloemfontein',
#        'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala', 'Kochi',
#        'Visakhapatnam', 'Raipur', 'Ranchi', 'Abu Dhabi', 'Sharjah',
#        'Dubai', 'Mohali'], dtype=object)

# %%
# Now we want to find table of 'cities' and count of total matches played there.
# groupby() is use to divide the dataframe on the basis of 'city' and separately count total id of each city
cities = ipl_df.groupby('city')[['id']].count()
cities
# Out:
#                  id
# city
# Abu Dhabi         7
# Ahmedabad        12
# Bengaluru        80
# Bloemfontein      2
# Cape Town         7
# Centurion        12
# Chandigarh       46
# Chennai          57
# Cuttack           7
# Delhi            74
# Dharamsala        9
# Dubai             7
# Durban           15
# East London       3
# Hyderabad        64
# Indore            9
# Jaipur           47
# Johannesburg      8
# Kanpur            4
# Kimberley         3
# Kochi             5
# Kolkata          77
# Mohali           10
# Mumbai          101
# Nagpur            3
# Port Elizabeth    7
# Pune             38
# Raipur            6
# Rajkot           10
# Ranchi            7
# Sharjah           6
# Visakhapatnam    13

# %% [markdown]
# Let arrange this data in a more organised manner

# %%
# it will rename the 'id' column,and inplace=True makes the changes permanent
cities.rename(columns={'id':'matches'},inplace=True)

#it will sort the data in ascending order of matches played in each city
#reset_index() is use to reset the index starting from 0
cities = cities.sort_values('matches',ascending=False).reset_index()

#To start the index with 1
cities.index=np.arange(1,len(cities)+1)

# background_gradient() use to create Heatmap within dataframe .The higher is the color shade, the larger is the value present.
cities.style.background_gradient()
# Out:
# <style type="text/css">
# #T_1b093_row0_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_1b093_row1_col1 {
#   background-color: #0569a5;
#   color: #f1f1f1;
# }
# #T_1b093_row2_col1 {
#   background-color: #056fae;
#   color: #f1f1f1;
# }
# #T_1b093_row3_col1 {
#   background-color: #0d75b3;
#   color: #f1f1f1;
# }
# #T_1b093_row4_col1 {
#   background-color: #358fc0;
#   color: #f1f1f1;
# }
# #T_1b093_row5_col1 {
#   background-color: #589ec8;
#   color: #f1f1f1;
# }
# #T_1b093_row6_col1 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_1b093_row7_col1 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_1b093_row8_col1 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_1b093_row9_col1 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_1b093_row10_col1 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_1b093_row11_col1, #T_1b093_row12_col1 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# ...

# %% [markdown]
# From above observation we can see that there are total 32 official location where ipl has been played from 2008-2019.

# %% [markdown]
# Now we plot the data of cities in a bar chart

# %%
# plt.figure is use to Create a new figure i.e boundary and in figsize we have to mention Width,height of boundary in inches.
plt.figure(figsize=(20,10))
# grid() use to draw grid lines
plt.grid()
plt.title('Number Of Matches Played In Each City',fontsize=15,bbox={'facecolor':'0.9','pad':5},pad=18)
#to draw the bar chart
# winter_r palette is used here for color of bars
sns.barplot(x='matches',y='city',data=cities,palette='winter')
plt.xlabel("Total matches played",fontsize=15)
plt.ylabel("City",fontsize=15)
plt.show()

# %% [markdown]
# From above bar plot it seems that Mumbai is the favourite location for IPL matches where maximum number of matches had been played followed by Bengaluru,kolkata and delhi.

# %% [markdown]
# ### Total matches played every year

# %%
season_df = ipl_df.groupby('Season')[['id']].count()
season_df
# Out:
#           id
# Season
# IPL-2008  58
# IPL-2009  57
# IPL-2010  60
# IPL-2011  73
# IPL-2012  74
# IPL-2013  76
# IPL-2014  60
# IPL-2015  59
# IPL-2016  60
# IPL-2017  59
# IPL-2018  60
# IPL-2019  60

# %%
# now arrange data in organised manner
season_df.rename(columns = {'id':'number of matches played','season':'season'},inplace=True)
season_df.style.background_gradient()
# Out:
# <style type="text/css">
# #T_a094a_row0_col0 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_a094a_row1_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_a094a_row2_col0, #T_a094a_row6_col0, #T_a094a_row8_col0, #T_a094a_row10_col0, #T_a094a_row11_col0 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# #T_a094a_row3_col0 {
#   background-color: #046096;
#   color: #f1f1f1;
# }
# #T_a094a_row4_col0 {
#   background-color: #045483;
#   color: #f1f1f1;
# }
# #T_a094a_row5_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_a094a_row7_col0, #T_a094a_row9_col0 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# </style>
# <table id="T_a094a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >number of matches played</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Season</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
# ...

# %% [markdown]
# Now we plot this data using heatmap() function of seaborn library

# %%
plt.figure(figsize=(10,5))
plt.title("Total matches played in each season",bbox={'facecolor':'0.9','pad':5},pad=18)

#The heatmap especially uses to show 2D data in graphical format.It is a type of chart that uses different shades 
#of colors to represent data values
sns.heatmap(season_df,cmap='bone');

# %% [markdown]
# From above observation we conclude that most number of matches had played in 2013,76 matches

# %% [markdown]
# ### Total matches won by each team

# %%
# First we'll extract our required data 
winner_df = ipl_df.groupby('winner')[['id']].count()
# sort this table in descending order
winner_df = winner_df.sort_values('id', ascending=False).reset_index()
# remove the data of 'Draw/Cancelled' bcoz it does not represent any team
winner_df=winner_df[:][winner_df['winner']!='Draw/Cancelled']

# %% [markdown]
# Now arrange this data in a more organised manner.

# %%
winner_df.rename(columns = {'id':'wins','winner':'Teams'},inplace=True)
winner_df.index=np.arange(1,len(winner_df)+1)
winner_df.style.background_gradient()
# Out:
# <style type="text/css">
# #T_bc2d7_row0_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_bc2d7_row1_col1 {
#   background-color: #034f7d;
#   color: #f1f1f1;
# }
# #T_bc2d7_row2_col1 {
#   background-color: #046198;
#   color: #f1f1f1;
# }
# #T_bc2d7_row3_col1 {
#   background-color: #056fae;
#   color: #f1f1f1;
# }
# #T_bc2d7_row4_col1 {
#   background-color: #0a73b2;
#   color: #f1f1f1;
# }
# #T_bc2d7_row5_col1 {
#   background-color: #1c7fb8;
#   color: #f1f1f1;
# }
# #T_bc2d7_row6_col1 {
#   background-color: #2484ba;
#   color: #f1f1f1;
# }
# #T_bc2d7_row7_col1 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_bc2d7_row8_col1 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_bc2d7_row9_col1 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_bc2d7_row10_col1 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_bc2d7_row11_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_bc2d7_">
# ...

# %% [markdown]
# Now we add colour to each team and plot wins vs teams.

# %%
#Plotting Wins vs Teams
#We will be using colour code of teams jersey to make it easily understandable
plt.figure(figsize=(15,7))
plt.xlabel('Teams',fontsize=20)
plt.ylabel('Wins',fontsize=20)
#to set the tick size to 40
plt.tick_params(labelsize=10)
#to rotate the ticks in x axis by 90 degree
plt.xticks(rotation=90)
plt.title('Matches Won By Each Team',fontsize=20,bbox={'facecolor':'0.9','pad':6},pad=25);
plt.bar(winner_df.Teams, winner_df.wins, color = ['blue','#FFD801','#461B7E','#C11B17','red','#000080','#F535AA','#F87217','#BCC6CC','#2C04A2','#E04F16','#632B72']);

# %% [markdown]
# From above bar chart,it seems that Mumbai Indians won most number of matches(109) followed by Chennai Super Kings(100) and Kolkata Knight Riders(92)

# %% [markdown]
# # Section 4 - Asking Interesting Questions on data

# %% [markdown]
# As part of this data analysis, it is very crucial to raise question and find answer to them. Here we will try to find out some of the most essential questions, that will help us in drawing a major conclusion from our dataset.

# %% [markdown]
# I will be asking following Questions:
#
# 1. What was the most preferred decision on winning toss i.e. Choose To Bat / Choose To Field
#
# 2. Which decision has proved most beneficial i.e Field / Bat ?
#
# 3. Who has won the Ipl Trophy most number of times ?
#
# 4. Which Venue(Stadium) has hosted the most number of matches ?
#
# 5. Who has been awarded with Player Of the Max maximum Number Of Times ?
#
# 6. In which season, most number of matches had been played ?
#
# 7. Which are the top 3 win by runs in IPL history ?
#
# 8. Which are the top 15 win by wickets in IPL history ?
#
# 9. Which Team Had maximum win by runs in final in IPL history ?
#
# 10. Which Team Had maximum win by wickets in final in IPL history ?
#
# 11. Which Team Had won most number of toss and match in final ?
#
# 12. Which team had played most number of finals?

# %% [markdown]
# ### Q1. What was the most preferred Decision On winning Toss i.e. Bat / Field

# %%
# to confirm the possibilities in toss decision i.e. bat/field
ipl_df.toss_decision.unique()
# Out:
# array(['field', 'bat'], dtype=object)

# %%
decision_df = ipl_df.groupby('toss_decision')[['id']].count()
decision_df = decision_df.sort_values('id').reset_index()


#Now we'll sort this data in more organised manner by renaming it's column's names.
decision_df.rename(columns={'id':'Total','toss_decision':'Decision'},inplace=True)
decision_df.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_47c1c_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Decision</th>
#       <th class="col_heading level0 col1" >Total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_47c1c_row0_col0" class="data row0 col0" >bat</td>
#       <td id="T_47c1c_row0_col1" class="data row0 col1" >293</td>
#     </tr>
#     <tr>
#       <td id="T_47c1c_row1_col0" class="data row1 col0" >field</td>
#       <td id="T_47c1c_row1_col1" class="data row1 col1" >463</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Lets plot the Result
plt.figure(figsize=(7,7))
plt.title("Preferred Decision",fontsize=20,bbox={'facecolor':'0.9','pad':6},pad=25)
plt.xlabel('Decision',fontsize=20)
plt.ylabel('Total',fontsize=20)
#to set the tick parameters
plt.tick_params(labelsize=20)
plt.grid()
plt.bar(decision_df.Decision, decision_df.Total, color=['#4863A0','#566D7E']);

# %%
print('The Most Preferred Decision After Winning Toss in the IPL Until 2019 has been "Choose to Field First"')
# Out:
# The Most Preferred Decision After Winning Toss in the IPL Until 2019 has been "Choose to Field First"

# %% [markdown]
# ### Q2. Which decision has proved most beneficial(result in winning) i.e Field / Bat first.

# %%
field_df = ipl_df.loc[(ipl_df['toss_winner'] == ipl_df['winner']) & (ipl_df['toss_decision'] == 'field'), ['id', 'winner','toss_decision']]
field_df.id.count()
# Out:
# 259

# %%
bat_df = ipl_df.loc[(ipl_df['toss_winner'] == ipl_df['winner']) & (ipl_df['toss_decision'] == 'bat'), ['id', 'winner','toss_decision']]
bat_df.id.count()
# Out:
# 134

# %%
dataframes = [bat_df, field_df]
#The concat() function in pandas is used to append either columns or rows from one DataFrame to another
result_df = pd.concat(dataframes)
result_df = result_df.groupby('toss_decision')[['id']].count()
result_df
# Out:
#                 id
# toss_decision
# bat            134
# field          259

# %%
# As from Earlier Analysis we know out of 756 Toss that were tossed (2008 - 2019) "463 times toss winning team Choose to Field First" and only "293 Times batting was choosen"
# Now Lets Plot the New Understanding Regarding the Success of these decisions
result_df = result_df.sort_values('id').reset_index()
result_df.rename(columns={'id':'Total','toss_decision':'Decision'},inplace=True)
#to hide the index column
result_df.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_09dea_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Decision</th>
#       <th class="col_heading level0 col1" >Total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_09dea_row0_col0" class="data row0 col0" >bat</td>
#       <td id="T_09dea_row0_col1" class="data row0 col1" >134</td>
#     </tr>
#     <tr>
#       <td id="T_09dea_row1_col0" class="data row1 col0" >field</td>
#       <td id="T_09dea_row1_col1" class="data row1 col1" >259</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Visualise it using bar chart
plt.figure(figsize=(7,7))
plt.title("Decision Success",fontsize=20,bbox={'facecolor':'0.9','pad':6},pad=25)
plt.xlabel('Decision',fontsize=20)
plt.ylabel('Total',fontsize=20)
# to set the ticks size
plt.tick_params(labelsize=20)
plt.bar(decision_df.Decision, decision_df.Total, color=['#4CC552','#4CC552']);
plt.bar(result_df.Decision, result_df.Total, color=['#00FF00','#00FF00']);
plt.legend(['Decision Taken','Decision Proved Right'],fontsize='larger');

# %% [markdown]
# We can see the fielding decision on winning toss has not only been most preferred one but it has also proven to be a good decision as almost 60% of the time it is proved right.

# %% [markdown]
# ### Q3. Who Has Won the Ipl Trophy Most Number of Times?

# %% [markdown]
# Now lets search For Team with Most Season Wins.
#
# We will have to extract the Final matches from the Entire Data.
#
# To do that we can sort the matches season wise and then select the last match of the season.

# %%
final_df = ipl_df.groupby('Season').tail(1).copy()
final_df=final_df.sort_values('Season')
final_df=final_df.reset_index(drop=True)


def highlight_data(x):
    df=x.copy()
    df.loc[:,:]='background-color:white'
    df.winner='background-color:lightgreen'
    return df
final_df.style.apply(highlight_data,axis=None)
# Out:
# <style type="text/css">
# ...

# %%
final_count_df=final_df.groupby('winner')[['id']].count()
#now arrange the data in a more organised manner.
final_count_df.rename(columns={'id':'no of times','winner':'winner'},inplace=True)
final_count_df=final_count_df.reset_index()
final_count_df.style.hide_index().background_gradient()
# Out:
# <style type="text/css">
# #T_909ee_row0_col1 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# #T_909ee_row1_col1, #T_909ee_row4_col1, #T_909ee_row5_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_909ee_row2_col1 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_909ee_row3_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_909ee_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >winner</th>
#       <th class="col_heading level0 col1" >no of times</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_909ee_row0_col0" class="data row0 col0" >Chennai Super Kings</td>
#       <td id="T_909ee_row0_col1" class="data row0 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_909ee_row1_col0" class="data row1 col0" >Deccan Chargers</td>
#       <td id="T_909ee_row1_col1" class="data row1 col1" >1</td>
#     </tr>
#     <tr>
# ...

# %%
# Create a function to print count of winning IPL seasons instead of percent on pie chart.
def func(pct, allvalues):
    absolute = int(pct / 100*np.sum(allvalues))
    return "{:d}".format(absolute)
# now let us visualise this data using pie chart.
plt.pie(list(final_count_df['no of times']),labels=list(final_count_df.winner),autopct = lambda pct: func(pct,list(final_count_df['no of times'])),explode=[0,0,0,0.1,0,0],radius=1.5,shadow=True,colors=['yellow','#BCC6CC','purple','blue','pink','#F87217'])
plt.title('No. of times a team won IPL',bbox={'facecolor':'0.9','pad':6},pad=78)
plt.show()

# %% [markdown]
# ### Q4. Which Venue(Stadium) has hosted the most number of matches?

# %%
# First extract the required data.
venue_df=ipl_df.groupby('venue')[['id']].count()
# Now arrange it in more organised manner
venue_df = venue_df.sort_values('id',ascending=False).reset_index()
venue_df.index=np.arange(1,len(venue_df)+1)
venue_df.rename(columns={'id':'Total matches played','venue':'Venue'},inplace=True)
venue_df.style.background_gradient()
# Out:
# <style type="text/css">
# #T_0cb9f_row0_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_0cb9f_row1_col1, #T_0cb9f_row2_col1 {
#   background-color: #03466e;
#   color: #f1f1f1;
# }
# #T_0cb9f_row3_col1 {
#   background-color: #045b8f;
#   color: #f1f1f1;
# }
# #T_0cb9f_row4_col1 {
#   background-color: #1077b4;
#   color: #f1f1f1;
# }
# #T_0cb9f_row5_col1 {
#   background-color: #358fc0;
#   color: #f1f1f1;
# }
# #T_0cb9f_row6_col1 {
#   background-color: #4295c3;
#   color: #f1f1f1;
# }
# #T_0cb9f_row7_col1 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_0cb9f_row8_col1 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_0cb9f_row9_col1, #T_0cb9f_row10_col1 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_0cb9f_row11_col1 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_0cb9f_row12_col1 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# #T_0cb9f_row13_col1, #T_0cb9f_row14_col1 {
# ...

# %%
# Visualise it using matplotlib and seaborn
plt.figure(figsize=(20,10))
plt.grid()
plt.title('Number Of Matches Played In Each City',fontsize=18,bbox={'facecolor':'0.9','pad':5},pad=18)
sns.barplot(x='Total matches played',y='Venue',data=venue_df,palette='rainbow')
plt.xlabel("Total matches played",fontsize=20)
plt.ylabel("Venue",fontsize=20)
plt.show()

# %% [markdown]
# So we can see the most number of matches were played at Eden Gardens(77) followed by Wankhede Stadium (73) and M Chinnaswamy Stadium (73).

# %% [markdown]
# ### Q5. Who has been awarded with Player Of the Match maximum Number Of Times?

# %%
#Lets Check how many players have been awarded with player of the match award
'Total players awarded with player of the match award are '+str(len(ipl_df.player_of_match.unique()))
# Out:
# 'Total players awarded with player of the match award are 227'

# %%
# Extract the required data
pom_df=ipl_df.groupby('player_of_match')[['id']].count()
pom_df = pom_df.sort_values('id',ascending=False).reset_index()
pom_df.rename(columns={'id':'No. of times','player_of_the_match':'Player_of_the_match'},inplace=True)

#Now from these players let extract top 10 players
pom_df = pom_df.head(10)
pom_df.index=np.arange(1,len(pom_df)+1)
pom_df.style.background_gradient()
# Out:
# <style type="text/css">
# #T_2b0c5_row0_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_2b0c5_row1_col1 {
#   background-color: #045687;
#   color: #f1f1f1;
# }
# #T_2b0c5_row2_col1, #T_2b0c5_row3_col1, #T_2b0c5_row4_col1 {
#   background-color: #589ec8;
#   color: #f1f1f1;
# }
# #T_2b0c5_row5_col1 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_2b0c5_row6_col1 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_2b0c5_row7_col1 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_2b0c5_row8_col1 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_2b0c5_row9_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_2b0c5_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >player_of_match</th>
#       <th class="col_heading level0 col1" >No. of times</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
# Now visualise it using matlotlib and seaborn
sns.barplot(x='player_of_match',y='No. of times',data=pom_df,palette='YlOrBr_r');
# pad  is use to set padding and bbox is use to put the title in a box
plt.title('Player of the match',fontsize=15,bbox={'facecolor':'0.9','pad':4},pad=18)
# To set the size of ticks
plt.tick_params(labelsize=12)
# To set the degree of rotation on x-ticks
plt.xticks(rotation=65)
plt.xlabel("Name of the Player",size=15)
plt.ylabel("No. of times",size=15);

# %% [markdown]
# ### Q6. In which season most number of matches had been played ?

# %%
# Extract the required data
season_df[season_df["number of matches played"]==season_df["number of matches played"].max()]
# Out:
#           number of matches played
# Season
# IPL-2013                        76

# %% [markdown]
# So We can see IPL-2013 had witnessed most number of matches

# %% [markdown]
# ### Q7. Which are the top 5 win by runs in IPL history?

# %%
# Extract the required data
max_win_run_df=ipl_df[['Season','winner','win_by_runs']]
# Now arrange it in more organised manner
max_win_run_df=max_win_run_df.sort_values('win_by_runs',ascending=False).head(5)

max_win_run_df.index=np.arange(1,len(max_win_run_df)+1)
max_win_run_df.style.background_gradient()
# Out:
# <style type="text/css">
# #T_05956_row0_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_05956_row1_col2 {
#   background-color: #04598c;
#   color: #f1f1f1;
# }
# #T_05956_row2_col2 {
#   background-color: #358fc0;
#   color: #f1f1f1;
# }
# #T_05956_row3_col2 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_05956_row4_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_05956_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Season</th>
#       <th class="col_heading level0 col1" >winner</th>
#       <th class="col_heading level0 col2" >win_by_runs</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_05956_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_05956_row0_col0" class="data row0 col0" >IPL-2017</td>
#       <td id="T_05956_row0_col1" class="data row0 col1" >Mumbai Indians</td>
# ...

# %%
# Visualise it using bar chart.
plt.title('Maximum win by runs',fontsize=15,bbox={'facecolor':'0.9','pad':5},pad=18)
# to draw the bar chart
colors=['blue','red','purple','red','red']
# the zip () function takes in one or more iterables as arguments. Make an iterator that aggregates elements from each of the iterables.
for w,x,y in zip(max_win_run_df.Season,max_win_run_df.win_by_runs,colors):
    plt.barh(w,x,color=y)

plt.xlabel('Win By Runs',fontsize=15)
plt.ylabel('Season',fontsize=15)
#The bbox_to_anchor keyword gives a great degree of control for manual legend placement simply specify the coordinate system of that location
plt.legend(max_win_run_df.winner[:3],bbox_to_anchor=(1.05,1));

# %% [markdown]
# ### Q8. Which are the top 15 win by wickets in IPL history?

# %%
# Extract the required data
max_win_wick_df=ipl_df[['Season','winner','win_by_wickets']]
# Arrange it in more organised manner
max_win_wick_df=max_win_wick_df.sort_values('win_by_wickets',ascending=False).head(15)
max_win_wick_df.index=np.arange(1,len(max_win_wick_df)+1)
max_win_wick_df.style.background_gradient()
# Out:
# <style type="text/css">
# #T_90d0c_row0_col2, #T_90d0c_row1_col2, #T_90d0c_row2_col2, #T_90d0c_row3_col2, #T_90d0c_row4_col2, #T_90d0c_row5_col2, #T_90d0c_row6_col2, #T_90d0c_row7_col2, #T_90d0c_row8_col2, #T_90d0c_row9_col2, #T_90d0c_row10_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_90d0c_row11_col2, #T_90d0c_row12_col2, #T_90d0c_row13_col2, #T_90d0c_row14_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_90d0c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Season</th>
#       <th class="col_heading level0 col1" >winner</th>
#       <th class="col_heading level0 col2" >win_by_wickets</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_90d0c_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_90d0c_row0_col0" class="data row0 col0" >IPL-2009</td>
# ...

# %% [markdown]
# From this it is concluded that total 11 times teams won by 10 wickets,out of which Royal Challengers Bangalore achieve this milestone most number of times(3 times)

# %% [markdown]
# ### Q9. Which Team Had maximum win by runs in final when toss decision is bat first and in which season?

# %%
max_win_runs_final_df=final_df[['Season','winner','win_by_runs']][final_df.win_by_runs>0]
#max_win_runs_final_df=max_win_runs_final_df.sort_values('win_by_runs',ascending=False)
max_win_runs_final_df.index=np.arange(1,len(max_win_runs_final_df)+1)
max_win_runs_final_df.style.background_gradient()
# Out:
# <style type="text/css">
# #T_9dd8c_row0_col2 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_9dd8c_row1_col2 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_9dd8c_row2_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_9dd8c_row3_col2 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_9dd8c_row4_col2 {
#   background-color: #187cb6;
#   color: #f1f1f1;
# }
# #T_9dd8c_row5_col2 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_9dd8c_row6_col2, #T_9dd8c_row7_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_9dd8c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Season</th>
#       <th class="col_heading level0 col1" >winner</th>
#       <th class="col_heading level0 col2" >win_by_runs</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9dd8c_level0_row0" class="row_heading level0 row0" >1</th>
# ...

# %% [markdown]
# ### Q10. Which Team Had maximum win by wickets in final in IPL history ?

# %%
max_win_wick_final_df=final_df[['Season','winner','win_by_wickets']][(final_df.win_by_wickets>0)]
max_win_wick_final_df.index=np.arange(1,len(max_win_wick_final_df)+1)
max_win_wick_final_df.style.background_gradient()
# Out:
# <style type="text/css">
# #T_942e7_row0_col2, #T_942e7_row2_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_942e7_row1_col2 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_942e7_row3_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_942e7_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Season</th>
#       <th class="col_heading level0 col1" >winner</th>
#       <th class="col_heading level0 col2" >win_by_wickets</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_942e7_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_942e7_row0_col0" class="data row0 col0" >IPL-2008</td>
#       <td id="T_942e7_row0_col1" class="data row0 col1" >Rajasthan Royals</td>
#       <td id="T_942e7_row0_col2" class="data row0 col2" >3</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# Now let us plot data obtained in Q9,Q10 using plot function

# %%
fig, axes = plt.subplots(1, 2, figsize=(25, 12))
axes[0].set_xlabel('Season',fontsize=20)
axes[0].set_ylabel('Runs',fontsize=20)
axes[0].set_title("Win by runs in final",fontsize=20,bbox={'facecolor':'0.9','pad':5},pad=18)
axes[0].xaxis.set_tick_params(labelsize=15)
axes[0].yaxis.set_tick_params(labelsize=15)
axes[0].plot(max_win_runs_final_df.Season,max_win_runs_final_df.win_by_runs,linewidth=3,marker='D',markersize=10)
axes[0].grid()
#The Axes.minorticks_on() function in axes module of matplotlib library is used to display minor ticks on the axes.
axes[0].minorticks_on()
# Now we draw minor and major grids
axes[0].grid(which='minor',linestyle=':',color='grey')
axes[0].grid(which='major',linestyle='-',color='cyan')

                                                                                      
axes[1].set_title("Win by wickets in final",fontsize=20,bbox={'facecolor':'0.9','pad':5},pad=18)
axes[1].set_xlabel('Season',fontsize=20)
axes[1].set_ylabel('Wickets',fontsize=20)
axes[1].xaxis.set_tick_params(labelsize=15)
axes[1].yaxis.set_tick_params(labelsize=15)
axes[1].plot(max_win_wick_final_df.Season,max_win_wick_final_df.win_by_wickets,color='r',linewidth=3,marker='D',markersize=10);
axes[1].grid()

# %% [markdown]
# ### Q11. Which Team Had won most number of toss and match in final?

# %%
toss_match_fin_df=final_df[['id','winner']][final_df.winner==final_df.toss_winner]
toss_match_fin_df=toss_match_fin_df.groupby('winner')[['id']].count()
toss_match_fin_df=toss_match_fin_df.sort_values('id',ascending=False).reset_index()
toss_match_fin_df.index=np.arange(1,len(toss_match_fin_df)+1)
toss_match_fin_df.rename(columns={'id':'No. of times','winner':'Team'},inplace=True)
toss_match_fin_df.style.background_gradient()
# Out:
# <style type="text/css">
# #T_1dc47_row0_col1, #T_1dc47_row1_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_1dc47_row2_col1, #T_1dc47_row3_col1, #T_1dc47_row4_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_1dc47_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Team</th>
#       <th class="col_heading level0 col1" >No. of times</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1dc47_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_1dc47_row0_col0" class="data row0 col0" >Chennai Super Kings</td>
#       <td id="T_1dc47_row0_col1" class="data row0 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_1dc47_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_1dc47_row1_col0" class="data row1 col0" >Mumbai Indians</td>
#       <td id="T_1dc47_row1_col1" class="data row1 col1" >3</td>
#     </tr>
# ...

# %%
# To print the count of winning toss and match in final intead of percentage on pie chart.
def func(pct, allvalues):
    absolute = int(pct / 100*np.sum(allvalues))
    return "{:d}".format(absolute)
# Visualise it using pie chart
plt.pie(toss_match_fin_df['No. of times'],radius=1.5,shadow=True,labels=list(toss_match_fin_df['Team']),explode=[0.1,0.1,0,0,0],colors=['yellow','blue','purple','pink','#F87217'],autopct= lambda pct: func(pct,list(toss_match_fin_df['No. of times'])))
plt.title('Count of winning toss and match in IPL final',bbox={'facecolor':'0.9','pad':6},pad=48)
plt.show()

# %% [markdown]
# ### Q12. Which team had played most number of finals?

# %%
# Preparing a data frame for our query.
df1=pd.DataFrame({'team_name':final_df.team1,'id':final_df.id})
df2=pd.DataFrame({'team_name':final_df.team2,'id':final_df.id})
team_final=pd.concat([df1,df2],ignore_index=True)
#Now arrange the data in a more organised manner
team_final=team_final.groupby('team_name')[['id']].count()
team_final.rename(columns={'id':'no. of times','team_name':'team_name'},inplace=True)
team_final=team_final.sort_values('no. of times',ascending=False).reset_index()
team_final=team_final.head()
team_final.style.background_gradient()
# Out:
# <style type="text/css">
# #T_7eb16_row0_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_7eb16_row1_col1 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_7eb16_row2_col1 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_7eb16_row3_col1, #T_7eb16_row4_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_7eb16_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >team_name</th>
#       <th class="col_heading level0 col1" >no. of times</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7eb16_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7eb16_row0_col0" class="data row0 col0" >Chennai Super Kings</td>
#       <td id="T_7eb16_row0_col1" class="data row0 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_7eb16_level0_row1" class="row_heading level0 row1" >1</th>
# ...

# %% [markdown]
# From above observation we conclude that Chennai Super Kings played final most number of times(8) followed by Mumbai Indians(5)

# %%
# Now plot the bar chart of our data using matplotlib
plt.bar(team_final['team_name'],team_final['no. of times'],color=['yellow','blue','red','purple','#F87217'])
plt.title('Team in final',fontsize=15,bbox={'facecolor':'0.9','pad':5},pad=18)
plt.tick_params(labelsize=12)
plt.xticks(rotation=90)
plt.xlabel("Teams",size=15)
plt.ylabel("No. of times",size=15)
plt.show()

# %% [markdown]
# # Section 5: Inferences and Conclusion

# %% [markdown]
# In this analysis I used the matches.csv file from the kaggle Datasets. Following are my conclusions about it
#
# 1. A total of 756 matches have been played from 2008 - 2019.
# 2. Out of these 756 matches 743 matches were played normally and had a normal result.
# 3. Most number of Matches were played in Mumbai (101 matches).
# 4. Mumbai Indian's Have Won the Most Number of Matches (109) followed by Chennai Super Kings (100 Matches).
# 5. IPL-2013 season hosted most number of matches (76).
# 6. Eden Gardens (Stadium) Hosted the Most Number of Matches (77) followed by wankhede Stadium (73) and M Chinnaswamy Stadium (73)
# 7. Chris Gayle has been the Man Of The Match Most Number of Times with "21" Awards followed by AB di Villiers (20) and MS Dhoni (17)
# 8. Mumbai Indians Have been the IPL Champions Most number of times (4) followed by Chennai Super Kings (3) and Kolkata Knight Riders(3).
# 10. Fielding decision on winning toss has not only been most preferred one but it has also proven to be a good decision as almost 60% of the time it is proved right.
# 11. Mumbai Indians won by maximum runs(146 runs) in IPL history followed by Royal Challengers Bangalore(144 runs) and Kolkata Knight Riders(140 runs).
# 12. Total 11 times teams won by 10 wickets,out of which Royal Challengers Bangalore achieve this milestone most number of times(3 times).
# 13. Chennai Super Kings played final most number of times(8) followed by Mumbai Indians(5).
# 14. Out of total 756 matches,result of total 9 matches was tie.
# 15. Chennai Super King won the ipl final with most no. of runs(58) in season(IPL-2011).
# 16. Chennai Super King won the ipl final with most no. of wickets(8) in season(IPL-2018).
# 15. Mumbai Indians and Chennai Super Kings have been the dominant Teams.

# %% [markdown]
# # Future Work
# The data set had 6 different csv Files. I will try to explore the 'Players.csv', 'Deliveries.csv' and others in detail

# %% [markdown]
# # References

# %% [markdown]
# The Starter Notebook: https://jovian.ml/aakashns/zerotopandas-course-project-starter
#
# Numpy Documentation: https://numpy.org/devdocs/user/quickstart.html
#
# User guide for Pandas: https://pandas.pydata.org/docs/user_guide/index.html
#
# Seaborn gallery: https://seaborn.pydata.org/examples/index.html
#
# Matplotlib gallery: https://matplotlib.org/3.1.1/gallery/index.html
